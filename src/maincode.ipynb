# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the YOLOv8n model
model = YOLO("best.pt")  # Pretrained on COCO dataset

# Initialize the camera (0 for laptop camera)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not access the camera.")
    exit()

# %%
while True:
    ret, frame = cap.read()  # Read a frame
    
    if not ret:
        print("Failed to capture frame. Exiting...")
        break

    # Run YOLO object detection
    results = model(frame)

    # Annotate the frame with detections
    annotated_frame = results[0].plot()  # Draw bounding boxes and labels

    # Display the annotated frame
    cv2.imshow("YOLOv8 Object Detection", annotated_frame)

    # Exit when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 256x320 (no detections), 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.9ms
# Speed: 0.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.2ms
# Speed: 1.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.0ms
# Speed: 0.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.6ms
# Speed: 0.0ms preprocess, 30.6ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 37.9ms
# Speed: 0.0ms preprocess, 37.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.9ms
# Speed: 1.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.4ms
# Speed: 0.0ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.0ms
# Speed: 0.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 36.9ms
# Speed: 0.0ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.2ms
# Speed: 1.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.4ms
# Speed: 1.0ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 38.5ms
# Speed: 0.0ms preprocess, 38.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.1ms
# Speed: 0.0ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 2 bubbles, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 2 bubbles, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 2 bubbles, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.5ms
# Speed: 1.0ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 2 bubbles, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.1ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.4ms
# Speed: 0.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 2 bubbles, 32.2ms
# Speed: 1.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 3 bubbles, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 2 bubbles, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 26.5ms
# Speed: 0.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 0.5ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.7ms
# Speed: 1.0ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.6ms
# Speed: 1.0ms preprocess, 31.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.4ms
# Speed: 0.0ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 0.9ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.9ms
# Speed: 1.0ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 37.3ms
# Speed: 1.0ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.9ms
# Speed: 0.0ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 35.5ms
# Speed: 0.0ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.6ms
# Speed: 1.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 39.6ms
# Speed: 0.0ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.5ms
# Speed: 0.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.4ms
# Speed: 0.5ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.2ms
# Speed: 0.0ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.0ms
# Speed: 0.5ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.8ms
# Speed: 0.0ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.5ms
# Speed: 0.0ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.7ms
# Speed: 0.0ms preprocess, 33.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 0.5ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 36.0ms
# Speed: 0.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 0.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.2ms
# Speed: 1.0ms preprocess, 29.2ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 44.7ms
# Speed: 0.0ms preprocess, 44.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.5ms
# Speed: 1.0ms preprocess, 28.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.9ms
# Speed: 0.4ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 0.5ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.5ms
# Speed: 0.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.2ms
# Speed: 1.0ms preprocess, 29.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.8ms
# Speed: 0.0ms preprocess, 30.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 37.5ms
# Speed: 0.0ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 1.5ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 34.0ms
# Speed: 0.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.4ms
# Speed: 1.0ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.7ms
# Speed: 0.0ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 29.0ms
# Speed: 0.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.7ms
# Speed: 0.0ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 bubble, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 0.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 37.3ms
# Speed: 0.0ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.6ms
# Speed: 1.4ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.0ms
# ...
#
# 0: 256x320 (no detections), 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 48.5ms
# Speed: 0.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 45.0ms
# Speed: 0.5ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 44.8ms
# Speed: 0.0ms preprocess, 44.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 49.7ms
# Speed: 0.0ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 39.8ms
# Speed: 0.0ms preprocess, 39.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 0.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.0ms
# Speed: 0.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.0ms
# Speed: 0.0ms preprocess, 32.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 28.3ms
# Speed: 0.0ms preprocess, 28.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 34.7ms
# Speed: 0.5ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 33.5ms
# Speed: 0.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 35.3ms
# Speed: 0.0ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 320)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       6     break
#       8 # Run YOLO object detection
# ----> 9 results = model(frame)
#      11 # Annotate the frame with detections
#      12 annotated_frame = results[0].plot()  # Draw bounding boxes and labels
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\engine\model.py:180, in Model.__call__(self, source, stream, **kwargs)
#     151 def __call__(
#     152     self,
#     153     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     154     stream: bool = False,
#     155     **kwargs,
#     156 ) -> list:
#     157     """
#     158     Alias for the predict method, enabling the model instance to be callable for predictions.
#     159
#    (...)
#     178         ...     print(f"Detected {len(r)} objects in image")
#     179     """
# --> 180     return self.predict(source, stream, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\engine\model.py:558, in Model.predict(self, source, stream, predictor, **kwargs)
#     556 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     557     self.predictor.set_prompts(prompts)
# --> 558 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\engine\predictor.py:173, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     171     return self.stream_inference(source, model, *args, **kwargs)
#     172 else:
# --> 173     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\engine\predictor.py:259, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     257 # Inference
#     258 with profilers[1]:
# --> 259     preds = self.inference(im, *args, **kwargs)
#     260     if self.args.embed:
#     261         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\engine\predictor.py:143, in BasePredictor.inference(self, im, *args, **kwargs)
#     137 """Runs inference on a given image using the specified model and arguments."""
#     138 visualize = (
#     139     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     140     if self.args.visualize and (not self.source_type.tensor)
#     141     else False
#     142 )
# --> 143 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\autobackend.py:527, in AutoBackend.forward(self, im, augment, visualize, embed)
#     525 # PyTorch
#     526 if self.pt or self.nn_module:
# --> 527     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     529 # TorchScript
#     530 elif self.jit:
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\tasks.py:112, in BaseModel.forward(self, x, *args, **kwargs)
#     110 if isinstance(x, dict):  # for cases of training and validating while training.
#     111     return self.loss(x, *args, **kwargs)
# --> 112 return self.predict(x, *args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\tasks.py:130, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     128 if augment:
#     129     return self._predict_augment(x)
# --> 130 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\tasks.py:151, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     149 if profile:
#     150     self._profile_one_layer(m, x, dt)
# --> 151 x = m(x)  # run
#     152 y.append(x if m.i in self.save else None)  # save output
#     153 if visualize:
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:238, in C2f.forward(self, x)
#     236 """Forward pass through C2f layer."""
#     237 y = list(self.cv1(x).chunk(2, 1))
# --> 238 y.extend(m(y[-1]) for m in self.m)
#     239 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:238, in <genexpr>(.0)
#     236 """Forward pass through C2f layer."""
#     237 y = list(self.cv1(x).chunk(2, 1))
# --> 238 y.extend(m(y[-1]) for m in self.m)
#     239 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:347, in Bottleneck.forward(self, x)
#     345 def forward(self, x):
#     346     """Applies the YOLO FPN to input data."""
# --> 347     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Apply convolution and activation without batch normalization."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\LENOVO\EL3rdsem\.venv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
